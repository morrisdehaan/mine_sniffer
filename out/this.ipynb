354837648107086, 4.957400974625689), (52.356996329864906, 4.952989713570777), (52.35691943469158, 4.953909050028631), (52.356551683828435, 4.954533020546861), (52.35648506098545, 4.955380767103172), (52.35602600824348, 4.956082958120226), (52.35591956082229, 4.956727839909744), (52.35549257684131, 4.9574172805349646), (52.35780559664365, 4.953284240902315), (52.357526865280406, 4.954130251501447), (52.35730467214571, 4.954982414634617), (52.35691916501353, 4.955644147607901), (52.35688846665012, 4.956232744570456), (52.35637269190923, 4.957199920212233), (52.356248456915544, 4.957826235153093)]

# %% [markdown]
# # Displaying on google maps

# %%
from IPython.display import HTML
import json

griddy = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Google Maps API Example</title>
    <meta name="viewport" content="initial-scale=1.0">
    <meta charset="UTF-8">
    <style>
        #map {{
            height: 100%;
        }}    
        html,
        body {{
            height: 100%;
            margin: 0;
            padding: 0;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <script>
        var map;

        function initMap() {{
            map = new google.maps.Map(document.getElementById('map'), {{
                center: {{ lat: 52.356252, lng: 4.956240 }},
                zoom: 14
            }});

            // Optional: Add a marker for each predicted coordinate
            var gridCoordinates = {json.dumps(actual_mines)};

            gridCoordinates.forEach(function(coord) {{
                var marker = new google.maps.Marker({{
                    position: {{ lat: coord[0], lng: coord[1] }},
                    map: map,
                    title: 'Griddy',
                    icon: {{
                        url: '/Users/ilaydahatipoglu/Desktop/bombb.png',  
                        scaledSize: new google.maps.Size(33, 29)
                    }}
                }});
            }});

            var newCoord = {json.dumps(predicted_mines)};

            newCoord.forEach(function(coord) {{
                var marker = new google.maps.Marker({{
                    position: {{ lat: coord[0], lng: coord[1] }},
                    map: map,
                    title: 'Target Marker',
                    icon: {{
                        url: '/Users/ilaydahatipoglu/Desktop/marky.png',
                        scaledSize: new google.maps.Size(33, 29)
                    }}
                }});
            }});
            
            heatmap = new google.maps.visualization.HeatmapLayer({{
                data: getHeatmapData(),
                map: map
            }});
        }}

        function getHeatmapData() {{
            var heatmapData = [];
            var newCoord = {json.dumps(predicted_mines)};;
            newCoord.forEach(function(coord) {{
                heatmapData.push(new google.maps.LatLng(coord[0], coord[1]));
            }});
            return heatmapData;

        }}
    </script>
    <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDou8uTds75RpXQfRa7jL5ShjFH6udzqJk&callback=initMap&libraries=visualization" async defer></script>
</body>
</html>
"""

griddy = griddy.replace('YOUR_API_KEY', 'AIzaSyDou8uTds75RpXQfRa7jL5ShjFH6udzqJk')

HTML(griddy)

with open("/Users/ilaydahatipoglu/Desktop/mine/heyo.html", "w") as html_file:
    html_file.write(griddy)
